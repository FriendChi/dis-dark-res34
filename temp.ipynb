# %%
from model.backbone import resnet1
import torch

model = resnet1('18', pretrained=False)
input_tensor = torch.randn(1, 3, 800, 320)  # 输入张量
output = model(input_tensor)
print(output[-1].shape)
# Out:
# torch.Size([1, 512, 25, 10])
